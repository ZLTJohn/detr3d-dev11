# %%
import os
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# %%
import pandas
import mmengine
# info = pandas.read_pickle('data/kitti-360/kitti360_infos_all.pkl')

# %%
from projects.detr3d.argo2_dataset import Kitti360Dataset
from projects.configs.extended_dataset import debug_all
import copy
from mmdet3d.utils import register_all_modules, replace_ceph_backend

# %%
register_all_modules()
cfg = copy.deepcopy(debug_all.K360_train)
cfg['ann_file'] = 'kitti360_infos_2013_05_28_drive_0009_sync.pkl'
cfg.pop('type')
cfg.pop('load_interval')
dataset = Kitti360Dataset(**cfg)
# Out:
# 11/23 06:05:03 - mmengine - INFO - ------------------------------
# 11/23 06:05:03 - mmengine - INFO - The length of the dataset: 12922
# 11/23 06:05:03 - mmengine - INFO - The number of instances per category in the dataset:
# +----------------------+--------+
# | category             | number |
# +----------------------+--------+
# | bicycle              | 23717  |
# | box                  | 0      |
# | bridge               | 0      |
# | building             | 0      |
# | bus                  | 195    |
# | car                  | 211715 |
# | caravan              | 605    |
# | garage               | 0      |
# | lamp                 | 0      |
# | motorcycle           | 8409   |
# | person               | 16306  |
# | pole                 | 0      |
# | rider                | 1505   |
# | smallpole            | 0      |
# | stop                 | 0      |
# | traffic light        | 0      |
# | traffic sign         | 0      |
# | trailer              | 4554   |
# | train                | 0      |
# | trash bin            | 0      |
# | truck                | 1956   |
# | tunnel               | 0      |
# | unknown construction | 0      |
# | unknown object       | 0      |
# | unknown vehicle      | 3448   |
# | vending machine      | 0      |
# +----------------------+--------+

# %%
from projects.detr3d.vis_zlt import visualizer_zlt
from projects.detr3d.detr3d import DETR3D
detr3d = DETR3D()
def visualize(vis,frame):
    batch_data_samples = frame['data_samples']
    batch_inputs_dict = frame['inputs']
    batch_input_metas = [batch_data_samples.metainfo]
    batch_input_metas = detr3d.add_lidar2img(batch_input_metas)
    batch_gt_instances_3d = [
        batch_data_samples.gt_instances_3d
    ]
    vis.visualize(batch_gt_instances_3d, batch_input_metas,
                    batch_inputs_dict.get('imgs', None))
vis = visualizer_zlt('debug/kitti-360')
for i in range(0,100000,1000):
    visualize(vis,dataset[i])
# Out:
# reference torch.Size([2, 3])
# 376 1408
# torch.Size([1, 1, 3])
# frame: 0
# reference torch.Size([3, 3])
# 376 1408
# torch.Size([1, 2, 3])
# frame: 1000
# reference torch.Size([3, 3])
# 376 1408
# torch.Size([1, 2, 3])
# frame: 2000
# reference torch.Size([4, 3])
# 376 1408
# torch.Size([1, 3, 3])
# frame: 3000
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 4000
# reference torch.Size([2, 3])
# 376 1408
# torch.Size([1, 1, 3])
# frame: 5000
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 6000
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 7000
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 8000
# reference torch.Size([3, 3])
# 376 1408
# torch.Size([1, 2, 3])
# frame: 9973
# reference torch.Size([4, 3])
# 376 1408
# torch.Size([1, 3, 3])
# frame: 10000
# reference torch.Size([3, 3])
# 376 1408
# torch.Size([1, 2, 3])
# frame: 11000
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 12000
# reference torch.Size([2, 3])
# 376 1408
# torch.Size([1, 1, 3])
# frame: 13000
# reference torch.Size([5, 3])
# 376 1408
# torch.Size([1, 4, 3])
# frame: 14000
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 15000
# reference torch.Size([3, 3])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 16
#      14 vis = visualizer_zlt('debug/kitti-360')
#      15 for i in range(0,100000,1000):
# ---> 16     visualize(vis,dataset[i])
#
# Cell In[10], line 12, in visualize(vis, frame)
#       8 batch_input_metas = detr3d.add_lidar2img(batch_input_metas)
#       9 batch_gt_instances_3d = [
#      10     batch_data_samples.gt_instances_3d
#      11 ]
# ---> 12 vis.visualize(batch_gt_instances_3d, batch_input_metas,
#      13                 batch_inputs_dict.get('imgs', None))
#
# File ~/mmdev11/detr3d-dev11/projects/detr3d/vis_zlt.py:172, in visualizer_zlt.visualize(self, instances_3d, img_meta, img, name_suffix, dirname, pause)
#     170 if img_meta.get('lidar_path'):
#     171     pc = self.load_pts(img_meta)
# --> 172     self.save_bev(pc, instances_3d, dirname, filename)
#     173 img_from_file = self.load_imgs(img_paths)
#     174 metacopy = copy(img_meta)
#
# File ~/mmdev11/detr3d-dev11/projects/detr3d/vis_zlt.py:382, in visualizer_zlt.save_bev(self, pts, instances_3d, dirname, out_name)
#     377         cx, cy = int(ref_pts_y[j]), int(ref_pts_x[j])
#     378         self.draw_arrowedLine(draw, (cx, cy), (fx, fy),
#     379                               width=3,
#     380                               color=color_front)
# --> 382 img.save(out_name)
#
# File ~/anaconda3/envs/mmdev11/lib/python3.8/site-packages/PIL/Image.py:2353, in Image.save(self, fp, format, **params)
#    2350         fp = builtins.open(filename, "w+b")
#    2352 try:
# -> 2353     save_handler(self, fp, filename)
#    2354 except Exception:
#    2355     if open_fp:
#
# File ~/anaconda3/envs/mmdev11/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:783, in _save(im, fp, filename)
#     779 # The EXIF info needs to be written as one block, + APP1, + one spare byte.
#     780 # Ensure that our buffer is big enough. Same with the icc_profile block.
#     781 bufsize = max(ImageFile.MAXBLOCK, bufsize, len(exif) + 5, len(extra) + 1)
# --> 783 ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#
# File ~/anaconda3/envs/mmdev11/lib/python3.8/site-packages/PIL/ImageFile.py:505, in _save(im, fp, tile, bufsize)
#     503     fh = fp.fileno()
#     504     fp.flush()
# --> 505     _encode_tile(im, fp, tile, bufsize, fh)
#     506 except (AttributeError, io.UnsupportedOperation) as exc:
#     507     _encode_tile(im, fp, tile, bufsize, None, exc)
#
# File ~/anaconda3/envs/mmdev11/lib/python3.8/site-packages/PIL/ImageFile.py:532, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     529                 break
#     530     else:
#     531         # slight speedup: compress to real file object
# --> 532         s = encoder.encode_to_file(fh, bufsize)
#     533 if s < 0:
#     534     raise OSError(f"encoder error {s} when writing image file") from exc
#
# KeyboardInterrupt:

# %%
from projects.detr3d.vis_zlt import visualizer_zlt
from projects.detr3d.detr3d import DETR3D
import os.path as osp
import numpy as np
from projects.detr3d.detr3d import DETR3D
detr3d = DETR3D()
vis = visualizer_zlt(debug_name='')
for i in range(8610,8620,2):
    frame = dataset[i]
    name = osp.basename(frame['data_samples'].lidar_path).split('.')[0]
    scene = frame['data_samples'].city_name
    inst = frame['data_samples'].gt_instances_3d[:2]
    batch_data_samples = frame['data_samples']
    batch_input_metas = [batch_data_samples.metainfo]
    batch_input_metas = detr3d.add_lidar2img(batch_input_metas)
    gt_bboxes_3d = inst.bboxes_3d
    corners_pt = np.array(gt_bboxes_3d.corners.view(-1, 3)).T
    print(name)
    # vis.visualize(inst, batch_input_metas,None,'test','debug/')
    vis.visualize_dataset_item(frame,name_suffix=name+'K_00', dirname='debug/kitti-360/'+scene)
# Out:
# 0000008970
# reference torch.Size([14, 3])
# 376 1408
# torch.Size([1, 13, 3])
# frame: 8610
# 0000008972
# reference torch.Size([13, 3])
# 376 1408
# torch.Size([1, 12, 3])
# frame: 8612
# 0000008974
# reference torch.Size([14, 3])
# 376 1408
# torch.Size([1, 13, 3])
# frame: 8614
# 0000008976
# reference torch.Size([17, 3])
# 376 1408
# torch.Size([1, 16, 3])
# frame: 8616
# 0000008978
# reference torch.Size([17, 3])
# 376 1408
# torch.Size([1, 16, 3])
# frame: 8618

# %%
from projects.detr3d.vis_zlt import visualizer_zlt
from projects.detr3d.detr3d import DETR3D
detr3d = DETR3D()
vis = visualizer_zlt(debug_name='')
def visualize(vis,frame):
    batch_data_samples = frame['data_samples']
    batch_inputs_dict = frame['inputs']
    batch_input_metas = [batch_data_samples.metainfo]
    batch_input_metas[0]['cam2img'] = [tempK]
    batch_input_metas[0]['ori_cam2img'] = [tempK]
    print(batch_input_metas[0]['ori_cam2img'])
    name = osp.basename(frame['data_samples'].lidar_path).split('.')[0]
    scene = frame['data_samples'].city_name
    batch_input_metas = detr3d.add_lidar2img(batch_input_metas)
    batch_gt_instances_3d = [
        batch_data_samples.gt_instances_3d
    ]
    vis.visualize(batch_gt_instances_3d, batch_input_metas,
                    batch_inputs_dict.get('imgs', None),name_suffix=name+'K_00', dirname='debug/kitti-360/'+scene)
for i in range(0,100,2):
    visualize(vis,dataset[i])
# Out:
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([2, 3])
# 376 1408
# torch.Size([1, 1, 3])
# frame: 0
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([3, 3])
# 376 1408
# torch.Size([1, 2, 3])
# frame: 2
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 4
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 6
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 8
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([11, 3])
# 376 1408
# torch.Size([1, 10, 3])
# frame: 10
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([11, 3])
# 376 1408
# torch.Size([1, 10, 3])
# frame: 12
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([11, 3])
# 376 1408
# torch.Size([1, 10, 3])
# frame: 14
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 16
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 18
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 20
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 22
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 24
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 26
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 28
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 30
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 32
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 34
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 36
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 38
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 40
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 42
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 44
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 46
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 48
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 50
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 52
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 54
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 56
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 58
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([6, 3])
# 376 1408
# torch.Size([1, 5, 3])
# frame: 60
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([6, 3])
# 376 1408
# torch.Size([1, 5, 3])
# frame: 62
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([5, 3])
# 376 1408
# torch.Size([1, 4, 3])
# frame: 64
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([5, 3])
# 376 1408
# torch.Size([1, 4, 3])
# frame: 66
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([5, 3])
# 376 1408
# torch.Size([1, 4, 3])
# frame: 68
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([5, 3])
# 376 1408
# torch.Size([1, 4, 3])
# frame: 70
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 72
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 74
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 76
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 78
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([7, 3])
# 376 1408
# torch.Size([1, 6, 3])
# frame: 80
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 82
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([8, 3])
# 376 1408
# torch.Size([1, 7, 3])
# frame: 84
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 86
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 88
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 90
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([9, 3])
# 376 1408
# torch.Size([1, 8, 3])
# frame: 92
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 94
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([12, 3])
# 376 1408
# torch.Size([1, 11, 3])
# frame: 96
# [array([[788.629315,   0.      , 687.158398],
#        [  0.      , 786.38223 , 317.752196],
#        [  0.      ,   0.      ,   1.      ]])]
# reference torch.Size([10, 3])
# 376 1408
# torch.Size([1, 9, 3])
# frame: 98

# %%
from projects.detr3d.kitti360_converter import CustomCameraPerspective
cam =CustomCameraPerspective('data/kitti-360/')

cam.K
# Out:
# array([[552.554261,   0.      , 682.049453,   0.      ],
#        [  0.      , 552.554261, 238.769549,   0.      ],
#        [  0.      ,   0.      ,   1.      ,   0.      ]])
